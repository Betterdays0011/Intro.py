# %% [markdown]
# <a href="https://colab.research.google.com/github/Betterdays0011/Intro.py/blob/main/Py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1.3.1
#
# **Task 1**
#
# Answer the following using Python:
#
# What is your name? Assign the value to the variable `name`
#
# How old are you? Assign the value to the variable `age`
#
# Are you a male or female? Assign the value to the variable `gender`
#
# What state did you come from? Assign the value to the variable `state`
#
# What language can you speak? Assign the value to the variable `language`
#
# True or False, do you smile today? Assign the value to the variable `smile`
#
# ---
#
# The list of the variables to create and assign values to are:
#
# `name`
#
# `age`
#
# `gender`
#
# `state`
#
# `language`
#
# `smile`

# %%
### CG T1
### write your code here:

name = "Abdulrasheed Abraham Sadiq"

age = 23

gender = "male"

state = "Kogi"

language = ["Igbirra", "English"]

smile = True

# %% [markdown]
# **Task 2**
#
# Explain why some variable names in the example are acceptable and why some are not in Python
#
# <img src="https://drive.google.com/uc?id=1NDbTGuy71awYbBNdwV3I14tAF7Fk91j_">

# %% [markdown]
# ### CG T2
# ### Write your answer here for sample variable names
#
# Looking at the examples, the acceptable names are valid because they use only letters, numbers, and underscores, and do not start with a number.
# They are also free of special characters like parentheses, hyphens, or ampersands, and contain no spaces.
# In contrast, the unacceptable names are invalid because they contain special symbols, start with a number, or include spaces.
